# %% [markdown]
# # Google Maps Lead Scraper — Colab
#
# This notebook sets up the environment and runs the scraper using Playwright and Supabase.

# %%
# Install missing Linux libraries for Chromium on Colab
# !apt-get update -y
# !apt-get install -y libatk1.0-0 libatk-bridge2.0-0 libcups2 libx11-xcb1 libxcomposite1 libxrandr2 libxdamage1 libxss1 libgconf-2-4 libnss3 libxkbfile1 libgbm-dev

# %%
# Install dependencies
# !pip install -r requirements.txt
# !python -m playwright install chromium

# %%
# Set required environment variables
import os
# Set your Supabase values here, or run these cells interactively
os.environ['SUPABASE_URL'] = 'https://your-project.supabase.co'
os.environ['SUPABASE_KEY'] = 'your-supabase-key'
os.environ['HEADLESS'] = 'true'
print('Supabase and HEADLESS env vars set')

# %%
# Run the worker (runs in foreground)
# !python worker_colab.py
